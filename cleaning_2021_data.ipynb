# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import glob, os
import csv
import datetime
import numpy as np
import time
import requests
import calendar
import seaborn as sns
import matplotlib.ticker as ticker
import matplotlib.cm as cm
import matplotlib as mpl
from matplotlib.gridspec import GridSpec

# %%
# find the file path of where the "all_2021_df.csv is saved on your particular local drive"

csv_path = "C:/Users/maxgl/Project1-Repo/data/all_2021_df.csv"
all_2021_df = pd.read_csv(csv_path,low_memory=False)
all_2021_df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  EF1237396C1D2DF4  electric_bike  2021-11-15 09:40:42  2021-11-15 09:48:22
# 1  4CA89455176FD912   classic_bike  2021-11-23 16:57:30  2021-11-23 17:02:04
# 2  3E632C5C54A1485C   classic_bike  2021-11-29 09:27:35  2021-11-29 09:51:22
# 3  9ED25F0388AC6226   classic_bike  2021-11-09 17:47:01  2021-11-09 17:51:15
# 4  3BF46E8C8FB64B36   classic_bike  2021-11-04 16:17:13  2021-11-04 16:21:01
#
#                   start_station_name start_station_id  \
# 0  Rhode Island & Connecticut Ave NW          31239.0
# 1  Rhode Island & Connecticut Ave NW          31239.0
# 2                12th & Irving St NE          31511.0
# 3      7th St & Massachusetts Ave NE          31647.0
# 4      7th St & Massachusetts Ave NE          31647.0
#
#                                     end_station_name end_station_id  \
# 0                                  Potomac & M St NW        31295.0
# 1                                     18th & R St NW        31278.0
# 2  Eastern Market Metro / Pennsylvania Ave & 8th ...        31613.0
# 3                    Columbus Circle / Union Station        31623.0
# 4                    Columbus Circle / Union Station        31623.0
#
#    start_lat  start_lng    end_lat    end_lng member_casual
# 0  38.905874 -77.039957  38.905309 -77.065044        member
# 1  38.905996 -77.039802  38.912648 -77.041834        member
# 2  38.928644 -76.990955  38.884095 -76.995234        member
# 3  38.892220 -76.996020  38.896960 -77.004930        member
# 4  38.892220 -76.996020  38.896960 -77.004930        member

# %%
# Rename Columns
all_2021_df.rename(columns={"ride_id":"Ride ID", "rideable_type":"Bike Type", "started_at": "Start Date", "ended_at": "End Date", "start_station_name": "Start Station", "start_station_id":"Start Station ID","end_station_name":"End Station", "end_station_id":"End Station ID","start_lat": "Starting Lat", "start_lng": "Starting Lng", "end_lat": "Ending Lat", "end_lng":"Ending Lng","member_casual": "Member type"},inplace=True)

# %%
# Print renamed columns
all_2021_df.head()
# Out:
#             Ride ID      Bike Type           Start Date             End Date  \
# 0  EF1237396C1D2DF4  electric_bike  2021-11-15 09:40:42  2021-11-15 09:48:22
# 1  4CA89455176FD912   classic_bike  2021-11-23 16:57:30  2021-11-23 17:02:04
# 2  3E632C5C54A1485C   classic_bike  2021-11-29 09:27:35  2021-11-29 09:51:22
# 3  9ED25F0388AC6226   classic_bike  2021-11-09 17:47:01  2021-11-09 17:51:15
# 4  3BF46E8C8FB64B36   classic_bike  2021-11-04 16:17:13  2021-11-04 16:21:01
#
#                        Start Station Start Station ID  \
# 0  Rhode Island & Connecticut Ave NW          31239.0
# 1  Rhode Island & Connecticut Ave NW          31239.0
# 2                12th & Irving St NE          31511.0
# 3      7th St & Massachusetts Ave NE          31647.0
# 4      7th St & Massachusetts Ave NE          31647.0
#
#                                          End Station End Station ID  \
# 0                                  Potomac & M St NW        31295.0
# 1                                     18th & R St NW        31278.0
# 2  Eastern Market Metro / Pennsylvania Ave & 8th ...        31613.0
# 3                    Columbus Circle / Union Station        31623.0
# 4                    Columbus Circle / Union Station        31623.0
#
#    Starting Lat  Starting Lng  Ending Lat  Ending Lng Member type
# 0     38.905874    -77.039957   38.905309  -77.065044      member
# 1     38.905996    -77.039802   38.912648  -77.041834      member
# 2     38.928644    -76.990955   38.884095  -76.995234      member
# 3     38.892220    -76.996020   38.896960  -77.004930      member
# 4     38.892220    -76.996020   38.896960  -77.004930      member

# %%
all_2021_df.dropna(how='any')
# Out:
#                   Ride ID      Bike Type           Start Date  \
# 0        EF1237396C1D2DF4  electric_bike  2021-11-15 09:40:42
# 1        4CA89455176FD912   classic_bike  2021-11-23 16:57:30
# 2        3E632C5C54A1485C   classic_bike  2021-11-29 09:27:35
# 3        9ED25F0388AC6226   classic_bike  2021-11-09 17:47:01
# 4        3BF46E8C8FB64B36   classic_bike  2021-11-04 16:17:13
# ...                   ...            ...                  ...
# 5499757  8C999F60CA429723   classic_bike  2021-12-15 18:26:44
# 5499758  CA9B6486BDC1D25A  electric_bike  2021-12-15 00:45:55
# 5499759  95957793A0807E8B   classic_bike  2021-12-06 14:17:45
# 5499760  99DA9A8F72185C79    docked_bike  2021-12-29 14:59:01
# 5499761  561DB870CDB1A6B0   classic_bike  2021-12-12 14:45:39
#
#                     End Date                      Start Station  \
# 0        2021-11-15 09:48:22  Rhode Island & Connecticut Ave NW
# 1        2021-11-23 17:02:04  Rhode Island & Connecticut Ave NW
# 2        2021-11-29 09:51:22                12th & Irving St NE
# 3        2021-11-09 17:51:15      7th St & Massachusetts Ave NE
# 4        2021-11-04 16:21:01      7th St & Massachusetts Ave NE
# ...                      ...                                ...
# 5499757  2021-12-15 18:34:25               14th & Belmont St NW
# 5499758  2021-12-15 00:49:46               14th & Belmont St NW
# 5499759  2021-12-06 14:29:26                     15th & P St NW
# 5499760  2021-12-29 16:29:40        10th St & L'Enfant Plaza SW
# 5499761  2021-12-12 14:46:45          Virginia Ave & 25th St NW
#
#         Start Station ID                                        End Station  \
# 0                31239.0                                  Potomac & M St NW
# 1                31239.0                                     18th & R St NW
# 2                31511.0  Eastern Market Metro / Pennsylvania Ave & 8th ...
# 3                31647.0                    Columbus Circle / Union Station
# 4                31647.0                    Columbus Circle / Union Station
# ...                  ...                                                ...
# 5499757          31119.0                         14th & Rhode Island Ave NW
# 5499758          31119.0                                14th & Irving St NW
# 5499759          31201.0                                14th & Irving St NW
# 5499760          31287.0                        10th St & L'Enfant Plaza SW
# 5499761          31297.0                          Virginia Ave & 25th St NW
#
#         End Station ID  Starting Lat  Starting Lng  Ending Lat  Ending Lng  \
# 0              31295.0     38.905874    -77.039957   38.905309  -77.065044
# 1              31278.0     38.905996    -77.039802   38.912648  -77.041834
# 2              31613.0     38.928644    -76.990955   38.884095  -76.995234
# 3              31623.0     38.892220    -76.996020   38.896960  -77.004930
# 4              31623.0     38.892220    -76.996020   38.896960  -77.004930
# ...                ...           ...           ...         ...         ...
# 5499757        31203.0     38.921074    -77.031887   38.908600  -77.032300
# 5499758        31124.0     38.920981    -77.031653   38.928552  -77.032224
# 5499759        31124.0     38.909801    -77.034427   38.928552  -77.032224
# 5499760        31287.0     38.884323    -77.026010   38.884323  -77.026010
# 5499761        31297.0     38.899500    -77.054155   38.899500  -77.054155
#
#         Member type
# 0            member
# 1            member
# 2            member
# 3            member
# 4            member
# ...             ...
# 5499757      casual
# 5499758      casual
# 5499759      member
# 5499760      casual
# 5499761      member
#
# [4909006 rows x 13 columns]

# %%
all_2021_df['Start Date'] = pd.to_datetime(all_2021_df['Start Date'])
all_2021_df['End Date'] = pd.to_datetime(all_2021_df['End Date'])
all_2021_df['day_of_week'] = all_2021_df['Start Date'].dt.day_name()
all_2021_df['year'] = all_2021_df['Start Date'].dt.year
all_2021_df['year']=pd.to_numeric(all_2021_df['year'])
all_2021_df['Day Type'] = all_2021_df['Start Date'].dt.dayofweek.apply(lambda x: 'Weekend' if x >= 5 else 'Weekday')
all_2021_df["Month"] = all_2021_df["Start Date"].dt.month
all_2021_df['Month'] = all_2021_df['Month'].apply(lambda x: calendar.month_abbr[x])
all_2021_df.head()
# Out:
#             Ride ID      Bike Type          Start Date            End Date  \
# 0  EF1237396C1D2DF4  electric_bike 2021-11-15 09:40:42 2021-11-15 09:48:22
# 1  4CA89455176FD912   classic_bike 2021-11-23 16:57:30 2021-11-23 17:02:04
# 2  3E632C5C54A1485C   classic_bike 2021-11-29 09:27:35 2021-11-29 09:51:22
# 3  9ED25F0388AC6226   classic_bike 2021-11-09 17:47:01 2021-11-09 17:51:15
# 4  3BF46E8C8FB64B36   classic_bike 2021-11-04 16:17:13 2021-11-04 16:21:01
#
#                        Start Station Start Station ID  \
# 0  Rhode Island & Connecticut Ave NW          31239.0
# 1  Rhode Island & Connecticut Ave NW          31239.0
# 2                12th & Irving St NE          31511.0
# 3      7th St & Massachusetts Ave NE          31647.0
# 4      7th St & Massachusetts Ave NE          31647.0
#
#                                          End Station End Station ID  \
# 0                                  Potomac & M St NW        31295.0
# 1                                     18th & R St NW        31278.0
# 2  Eastern Market Metro / Pennsylvania Ave & 8th ...        31613.0
# 3                    Columbus Circle / Union Station        31623.0
# 4                    Columbus Circle / Union Station        31623.0
#
#    Starting Lat  Starting Lng  Ending Lat  Ending Lng Member type day_of_week  \
# 0     38.905874    -77.039957   38.905309  -77.065044      member      Monday
# 1     38.905996    -77.039802   38.912648  -77.041834      member     Tuesday
# 2     38.928644    -76.990955   38.884095  -76.995234      member      Monday
# 3     38.892220    -76.996020   38.896960  -77.004930      member     Tuesday
# 4     38.892220    -76.996020   38.896960  -77.004930      member    Thursday
#
#    year Day Type Month
# 0  2021  Weekday   Nov
# 1  2021  Weekday   Nov
# 2  2021  Weekday   Nov
# 3  2021  Weekday   Nov
# 4  2021  Weekday   Nov

# %%
# Created “Duration” column, to calculate duration of ride in ‘seconds’
all_2021_df['Duration']=(all_2021_df['End Date']-all_2021_df['Start Date']).dt.total_seconds()
all_2021_df['Duration']=all_2021_df[['Duration']].astype(int)
all_2021_df.head()
# Out:
#             Ride ID      Bike Type          Start Date            End Date  \
# 0  EF1237396C1D2DF4  electric_bike 2021-11-15 09:40:42 2021-11-15 09:48:22
# 1  4CA89455176FD912   classic_bike 2021-11-23 16:57:30 2021-11-23 17:02:04
# 2  3E632C5C54A1485C   classic_bike 2021-11-29 09:27:35 2021-11-29 09:51:22
# 3  9ED25F0388AC6226   classic_bike 2021-11-09 17:47:01 2021-11-09 17:51:15
# 4  3BF46E8C8FB64B36   classic_bike 2021-11-04 16:17:13 2021-11-04 16:21:01
#
#                        Start Station Start Station ID  \
# 0  Rhode Island & Connecticut Ave NW          31239.0
# 1  Rhode Island & Connecticut Ave NW          31239.0
# 2                12th & Irving St NE          31511.0
# 3      7th St & Massachusetts Ave NE          31647.0
# 4      7th St & Massachusetts Ave NE          31647.0
#
#                                          End Station End Station ID  \
# 0                                  Potomac & M St NW        31295.0
# 1                                     18th & R St NW        31278.0
# 2  Eastern Market Metro / Pennsylvania Ave & 8th ...        31613.0
# 3                    Columbus Circle / Union Station        31623.0
# 4                    Columbus Circle / Union Station        31623.0
#
#    Starting Lat  Starting Lng  Ending Lat  Ending Lng Member type day_of_week  \
# 0     38.905874    -77.039957   38.905309  -77.065044      member      Monday
# 1     38.905996    -77.039802   38.912648  -77.041834      member     Tuesday
# 2     38.928644    -76.990955   38.884095  -76.995234      member      Monday
# 3     38.892220    -76.996020   38.896960  -77.004930      member     Tuesday
# 4     38.892220    -76.996020   38.896960  -77.004930      member    Thursday
#
#    year Day Type Month  Duration
# 0  2021  Weekday   Nov       460
# 1  2021  Weekday   Nov       274
# 2  2021  Weekday   Nov      1427
# 3  2021  Weekday   Nov       254
# 4  2021  Weekday   Nov       228

# %%
# Convert "Start Date" and "End Date" columns to datetime
all_2021_df['Start Date'] = pd.to_datetime(all_2021_df['Start Date'])
all_2021_df['End Date'] = pd.to_datetime(all_2021_df['End Date'])
# Create new columns for time components
all_2021_df['Start Time'] = all_2021_df['Start Date'].dt.time
all_2021_df['End Time'] = all_2021_df['End Date'].dt.time
# Convert "Start Date" and "End Date" columns to date
all_2021_df['Start Date'] = all_2021_df['Start Date'].dt.date
all_2021_df['End Date'] = all_2021_df['End Date'].dt.date
# Convert "Start Date" and "End Date" columns back to datetime with combined date and time
all_2021_df['Start Date'] = pd.to_datetime(all_2021_df['Start Date'].astype(str) + ' ' + all_2021_df['Start Time'].astype(str))
all_2021_df['End Date'] = pd.to_datetime(all_2021_df['End Date'].astype(str) + ' ' + all_2021_df['End Time'].astype(str))
# Convert "Start Date" column to datetime
all_2021_df['Start Date'] = pd.to_datetime(all_2021_df['Start Date'])
# Extract day of the week and year
all_2021_df['Day of Week'] = all_2021_df['Start Date'].dt.day_name()
all_2021_df['Year'] = all_2021_df['Start Date'].dt.year
all_2021_df['Year'] = pd.to_numeric(all_2021_df['Year'])
# Remove time from "Start Date" and "End Date" columns
all_2021_df['Start Date'] = all_2021_df['Start Date'].dt.date
all_2021_df['End Date'] = all_2021_df['End Date'].dt.date
# Display the updated DataFrame
all_2021_df.head()
# Out:
#             Ride ID      Bike Type  Start Date    End Date  \
# 0  EF1237396C1D2DF4  electric_bike  2021-11-15  2021-11-15
# 1  4CA89455176FD912   classic_bike  2021-11-23  2021-11-23
# 2  3E632C5C54A1485C   classic_bike  2021-11-29  2021-11-29
# 3  9ED25F0388AC6226   classic_bike  2021-11-09  2021-11-09
# 4  3BF46E8C8FB64B36   classic_bike  2021-11-04  2021-11-04
#
#                        Start Station Start Station ID  \
# 0  Rhode Island & Connecticut Ave NW          31239.0
# 1  Rhode Island & Connecticut Ave NW          31239.0
# 2                12th & Irving St NE          31511.0
# 3      7th St & Massachusetts Ave NE          31647.0
# 4      7th St & Massachusetts Ave NE          31647.0
#
#                                          End Station End Station ID  \
# 0                                  Potomac & M St NW        31295.0
# 1                                     18th & R St NW        31278.0
# 2  Eastern Market Metro / Pennsylvania Ave & 8th ...        31613.0
# 3                    Columbus Circle / Union Station        31623.0
# 4                    Columbus Circle / Union Station        31623.0
#
#    Starting Lat  Starting Lng  ...  Member type  day_of_week  year Day Type  \
# 0     38.905874    -77.039957  ...       member       Monday  2021  Weekday
# 1     38.905996    -77.039802  ...       member      Tuesday  2021  Weekday
# 2     38.928644    -76.990955  ...       member       Monday  2021  Weekday
# 3     38.892220    -76.996020  ...       member      Tuesday  2021  Weekday
# 4     38.892220    -76.996020  ...       member     Thursday  2021  Weekday
#
#    Month Duration Start Time  End Time Day of Week  Year
# 0    Nov      460   09:40:42  09:48:22      Monday  2021
# 1    Nov      274   16:57:30  17:02:04     Tuesday  2021
# 2    Nov     1427   09:27:35  09:51:22      Monday  2021
# 3    Nov      254   17:47:01  17:51:15     Tuesday  2021
# 4    Nov      228   16:17:13  16:21:01    Thursday  2021
#
# [5 rows x 22 columns]

# %%
all_2021_df = all_2021_df.drop(['year', 'day_of_week'], axis=1)
all_2021_df.head()
# Out:
#             Ride ID      Bike Type  Start Date    End Date  \
# 0  EF1237396C1D2DF4  electric_bike  2021-11-15  2021-11-15
# 1  4CA89455176FD912   classic_bike  2021-11-23  2021-11-23
# 2  3E632C5C54A1485C   classic_bike  2021-11-29  2021-11-29
# 3  9ED25F0388AC6226   classic_bike  2021-11-09  2021-11-09
# 4  3BF46E8C8FB64B36   classic_bike  2021-11-04  2021-11-04
#
#                        Start Station Start Station ID  \
# 0  Rhode Island & Connecticut Ave NW          31239.0
# 1  Rhode Island & Connecticut Ave NW          31239.0
# 2                12th & Irving St NE          31511.0
# 3      7th St & Massachusetts Ave NE          31647.0
# 4      7th St & Massachusetts Ave NE          31647.0
#
#                                          End Station End Station ID  \
# 0                                  Potomac & M St NW        31295.0
# 1                                     18th & R St NW        31278.0
# 2  Eastern Market Metro / Pennsylvania Ave & 8th ...        31613.0
# 3                    Columbus Circle / Union Station        31623.0
# 4                    Columbus Circle / Union Station        31623.0
#
#    Starting Lat  Starting Lng  Ending Lat  Ending Lng Member type Day Type  \
# 0     38.905874    -77.039957   38.905309  -77.065044      member  Weekday
# 1     38.905996    -77.039802   38.912648  -77.041834      member  Weekday
# 2     38.928644    -76.990955   38.884095  -76.995234      member  Weekday
# 3     38.892220    -76.996020   38.896960  -77.004930      member  Weekday
# 4     38.892220    -76.996020   38.896960  -77.004930      member  Weekday
#
#   Month  Duration Start Time  End Time Day of Week  Year
# 0   Nov       460   09:40:42  09:48:22      Monday  2021
# 1   Nov       274   16:57:30  17:02:04     Tuesday  2021
# 2   Nov      1427   09:27:35  09:51:22      Monday  2021
# 3   Nov       254   17:47:01  17:51:15     Tuesday  2021
# 4   Nov       228   16:17:13  16:21:01    Thursday  2021

# %%
# Get today's date
today = datetime.date.today()
# Convert "Start Time" and "End Time" to datetime
all_2021_df['Start Time'] = pd.to_datetime(today.strftime('%Y-%m-%d') + ' ' + all_2021_df['Start Time'].astype(str))
all_2021_df['End Time'] = pd.to_datetime(today.strftime('%Y-%m-%d') + ' ' + all_2021_df['End Time'].astype(str))
# Convert time to AM/PM format
all_2021_df['Start Time'] = all_2021_df['Start Time'].dt.strftime('%I:%M %p')
all_2021_df['End Time'] = all_2021_df['End Time'].dt.strftime('%I:%M %p')
# Display the updated DataFrame
all_2021_df.head()
# Out:
#             Ride ID      Bike Type  Start Date    End Date  \
# 0  EF1237396C1D2DF4  electric_bike  2021-11-15  2021-11-15
# 1  4CA89455176FD912   classic_bike  2021-11-23  2021-11-23
# 2  3E632C5C54A1485C   classic_bike  2021-11-29  2021-11-29
# 3  9ED25F0388AC6226   classic_bike  2021-11-09  2021-11-09
# 4  3BF46E8C8FB64B36   classic_bike  2021-11-04  2021-11-04
#
#                        Start Station Start Station ID  \
# 0  Rhode Island & Connecticut Ave NW          31239.0
# 1  Rhode Island & Connecticut Ave NW          31239.0
# 2                12th & Irving St NE          31511.0
# 3      7th St & Massachusetts Ave NE          31647.0
# 4      7th St & Massachusetts Ave NE          31647.0
#
#                                          End Station End Station ID  \
# 0                                  Potomac & M St NW        31295.0
# 1                                     18th & R St NW        31278.0
# 2  Eastern Market Metro / Pennsylvania Ave & 8th ...        31613.0
# 3                    Columbus Circle / Union Station        31623.0
# 4                    Columbus Circle / Union Station        31623.0
#
#    Starting Lat  Starting Lng  Ending Lat  Ending Lng Member type Day Type  \
# 0     38.905874    -77.039957   38.905309  -77.065044      member  Weekday
# 1     38.905996    -77.039802   38.912648  -77.041834      member  Weekday
# 2     38.928644    -76.990955   38.884095  -76.995234      member  Weekday
# 3     38.892220    -76.996020   38.896960  -77.004930      member  Weekday
# 4     38.892220    -76.996020   38.896960  -77.004930      member  Weekday
#
#   Month  Duration Start Time  End Time Day of Week  Year
# 0   Nov       460   09:40 AM  09:48 AM      Monday  2021
# 1   Nov       274   04:57 PM  05:02 PM     Tuesday  2021
# 2   Nov      1427   09:27 AM  09:51 AM      Monday  2021
# 3   Nov       254   05:47 PM  05:51 PM     Tuesday  2021
# 4   Nov       228   04:17 PM  04:21 PM    Thursday  2021

# %%
all_2021_df.to_csv('all_2021_data.csv', index=False)
