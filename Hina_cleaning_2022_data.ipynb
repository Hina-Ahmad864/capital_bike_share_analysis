# %%
import pandas as pd

# %%
# find the file path of where the "all_2021_df.csv is saved on your particular local drive"

csv_path = "/Users/hinaahmad/ClassRepository__2023/project_1_repo/2022_unclean_data/all_2022_df.csv"
all_2022_df = pd.read_csv(csv_path)
all_2022_df.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  C40CF15D0DBE584E  classic_bike  2022-09-23 18:42:27  2022-09-24 08:27:11
# 1  3788C1944643B399  classic_bike  2022-09-22 01:35:01  2022-09-22 01:49:59
# 2  A9E14A3286BB0922  classic_bike  2022-09-16 17:04:11  2022-09-16 17:08:40
# 3  77518ADEB4313901  classic_bike  2022-09-29 17:24:21  2022-09-29 18:32:05
# 4  7B99FCADC829EAC0  classic_bike  2022-09-13 23:51:12  2022-09-14 00:35:14
#
#                           start_station_name  start_station_id  \
# 0                 Georgia Ave & Morton St NW           31419.0
# 1                              7th & T St NW           31109.0
# 2  7th & F St NW / National Portrait Gallery           31232.0
# 3    14th & D St NW / Ronald Reagan Building           31231.0
# 4             New Hampshire Ave & 24th St NW           31275.0
#
#                             end_station_name  end_station_id  start_lat  \
# 0  14th St Heights / 14th & Crittenden St NW         31402.0  38.932128
# 1              7th St & Massachusetts Ave NE         31647.0  38.915693
# 2                 North Capitol St & F St NW         31624.0  38.897283
# 3                   4th & East Capitol St NE         31618.0  38.894514
# 4             New Hampshire Ave & 24th St NW         31275.0  38.901755
#
#    start_lng    end_lat    end_lng member_casual
# 0 -77.023500  38.947774 -77.032818        member
# 1 -77.021703  38.892220 -76.996020        member
# 2 -77.022191  38.897446 -77.009888        member
# 3 -77.031617  38.889955 -77.000349        casual
# 4 -77.051084  38.901755 -77.051084        casual

# %%
all_2022_df.rename(columns={"ride_id":"Ride ID", "rideable_type":"Bike Type", "started_at": "Start Date", "ended_at": "End Date", "start_station_name": "Start Station", "start_station_id":"Start Station ID","end_station_name":"End Station", "end_station_id":"End Station ID","start_lat": "Starting Lat", "start_lng": "Starting Lng", "end_lat": "Ending Lat", "end_lng":"Ending Lng","member_casual": "Member type"},inplace=True)

# %%
all_2022_df.head()
# Out:
#             Ride ID     Bike Type           Start Date             End Date  \
# 0  C40CF15D0DBE584E  classic_bike  2022-09-23 18:42:27  2022-09-24 08:27:11
# 1  3788C1944643B399  classic_bike  2022-09-22 01:35:01  2022-09-22 01:49:59
# 2  A9E14A3286BB0922  classic_bike  2022-09-16 17:04:11  2022-09-16 17:08:40
# 3  77518ADEB4313901  classic_bike  2022-09-29 17:24:21  2022-09-29 18:32:05
# 4  7B99FCADC829EAC0  classic_bike  2022-09-13 23:51:12  2022-09-14 00:35:14
#
#                                Start Station  Start Station ID  \
# 0                 Georgia Ave & Morton St NW           31419.0
# 1                              7th & T St NW           31109.0
# 2  7th & F St NW / National Portrait Gallery           31232.0
# 3    14th & D St NW / Ronald Reagan Building           31231.0
# 4             New Hampshire Ave & 24th St NW           31275.0
#
#                                  End Station  End Station ID  Starting Lat  \
# 0  14th St Heights / 14th & Crittenden St NW         31402.0     38.932128
# 1              7th St & Massachusetts Ave NE         31647.0     38.915693
# 2                 North Capitol St & F St NW         31624.0     38.897283
# 3                   4th & East Capitol St NE         31618.0     38.894514
# 4             New Hampshire Ave & 24th St NW         31275.0     38.901755
#
#    Starting Lng  Ending Lat  Ending Lng Member type
# 0    -77.023500   38.947774  -77.032818      member
# 1    -77.021703   38.892220  -76.996020      member
# 2    -77.022191   38.897446  -77.009888      member
# 3    -77.031617   38.889955  -77.000349      casual
# 4    -77.051084   38.901755  -77.051084      casual
